# %%
import pandas as pd
import seaborn as sns

# %%
issues_dataframe = pd.read_pickle("/media/zafar/Windows/data/issues_data.pkl")

# %%
issues_plot = sns.pairplot(issues_dataframe)
issues_plot.fig.suptitle("Issues vs Stars", y = 1.0, fontsize=18)
# Out:
# Text(0.5,1,'Issues vs Stars')

# %%
dataframe1 = pd.read_pickle("/media/zafar/Windows/data/dataframe1.pkl")

# %%
df_plot = sns.pairplot(dataframe1)
df_plot.fig.suptitle("Features Comparison", y = 1.00, fontsize=18)
# Out:
# Text(0.5,1,'Features Comparison')
